# %% [markdown]
# # Installation

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print("GPU is connected")
else:
    print("Using CPU")
# Out:
# GPU is connected

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Access Google Drive Folder
import os
os.chdir("gdrive/MyDrive")

# %%
# Create YOLOv8 root folder
# !mkdir yolov8n-wood

# %%
# Go to YOLOv8 root folder
# %cd yolov8n-wood
# Out:
# /content/gdrive/MyDrive/yolov8n-wood

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.2/112.6 GB disk)

# %% [markdown]
# # YOLOv8n model average Inference time and FPS calculation

# %%
import time
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/yolov8n-wood/best-YOLOv8n.pt')
source = '/content/gdrive/MyDrive/yolov8n-wood/test'

start_time = time.time()
results = model.predict(source=source, save=True)
end_time = time.time()

fps = len(results) / (end_time - start_time)
print(f"FPS: {fps}")
# Out:
# image 1/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600059.bmp: 256x640 1 knot with crack, 8.0ms
# image 2/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600069.bmp: 256x640 1 live knot, 2 dead knots, 10.4ms
# image 3/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600075.bmp: 256x640 1 live knot, 1 dead knot, 1 knot missing, 12.5ms
# image 4/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600079.bmp: 256x640 2 live knots, 8.6ms
# image 5/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600080.bmp: 256x640 1 live knot, 1 knot with crack, 8.8ms
# image 6/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600081.bmp: 256x640 1 live knot, 1 dead knot, 9.0ms
# image 7/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600082.bmp: 256x640 1 live knot, 2 dead knots, 8.7ms
# image 8/70 /content/gdrive/MyDrive/yolov8n-wood/test/106700065.bmp: 256x640 2 live knots, 11.8ms
# image 9/70 /content/gdrive/MyDrive/yolov8n-wood/test/106700069.bmp: 256x640 4 live knots, 8.4ms
# ...

# %% [markdown]
# # Proposed YOLO-WDD model average Inference time and FPS calculation

# %%
import time
from ultralytics import YOLO

model = YOLO('/content/gdrive/MyDrive/yolov8n-wood/best-YOLO-WDD.pt')
source = '/content/gdrive/MyDrive/yolov8n-wood/test'

start_time = time.time()
results = model.predict(source=source, save=True)
end_time = time.time()

fps = len(results) / (end_time - start_time)
print(f"FPS: {fps}")
# Out:
# image 1/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600059.bmp: 256x640 1 live knot, 1 knot with crack, 6.9ms
# image 2/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600069.bmp: 256x640 1 live knot, 2 dead knots, 6.6ms
# image 3/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600075.bmp: 256x640 1 live knot, 1 dead knot, 1 knot missing, 6.6ms
# image 4/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600079.bmp: 256x640 2 live knots, 6.2ms
# image 5/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600080.bmp: 256x640 1 live knot, 1 knot with crack, 6.1ms
# image 6/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600081.bmp: 256x640 1 live knot, 1 dead knot, 6.9ms
# image 7/70 /content/gdrive/MyDrive/yolov8n-wood/test/106600082.bmp: 256x640 1 live knot, 2 dead knots, 6.3ms
# image 8/70 /content/gdrive/MyDrive/yolov8n-wood/test/106700065.bmp: 256x640 2 live knots, 6.3ms
# image 9/70 /content/gdrive/MyDrive/yolov8n-wood/test/106700069.bmp: 256x640 4 live knots, 6.5ms
# ...
